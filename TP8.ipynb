# %% [markdown]
# # Ficha tÃ©cnica
#
# __identificador__: aulaP8;
#
# __tÃ­tulo__: Processamento de datasets;
#
# __data inÃ­cio__: 2021-11-29;
#
# __autor__: JosÃ© Carlos Ramalho, D1513;
#
# __resumo__: Nesta aula, irÃ¡s fazer exercÃ­cios sobre leitura de datasets, seu processamento e produÃ§Ã£o de dados estatÃ­sticos.

# %% [markdown]
# ## Dataset
#
# Para a resoluÃ§Ã£o dos exercÃ­cios desta ficha, descarrega o dataset de exames mÃ©dicos desportivos do site da UC.
#
# ### Estrutura do dataset
# O dataset tem a seguinte estrutura:
#
# ```
# _id,index,dataEMD,nome/primeiro,nome/Ãºltimo,idade,gÃ©nero,morada,modalidade,clube,email,federado,resultado
# 6045074cd77860ac9483d34e,0,2020-02-25,Delgado,Gay,28,F,Gloucester,BTT,ACRroriz,delgado.gay@acrroriz.biz,true,true
# 6045074ca6adebd591b5d239,1,2019-07-31,Foreman,Prince,34,M,Forestburg,Ciclismo,ACDRcrespos,foreman.prince@acdrcrespos.org,false,true
# 6045074c221e2fdf430e9ef0,2,2021-01-06,Cheryl,Berger,21,M,Umapine,Basquetebol,Vitoria,cheryl.berger@vitoria.biz,false,true
# 6045074c529cbdce549d3923,3,2020-11-19,Graves,Goff,29,F,Babb,Andebol,AVCfamalicÃ£o,graves.goff@avcfamalicÃ£o.co.uk,false,false
# 6045074c3319a0f9e79aad87,4,2019-09-01,Mckay,Bolton,29,F,Chilton,Futebol,ACDRcrespos,mckay.bolton@acdrcrespos.me,false,false
# 6045074c222607e7520ffd24,5,2019-10-07,Marla,Kelley,22,M,Clarence,Atletismo,AmigosMontanha,marla.kelley@amigosmontanha.tv,false,false
#
# ...
# ```

# %% [markdown]
# ## Leitura (exercÃ­cio 1)
#
# Depois de pensares num modelo adequado especifica a funÃ§Ã£o que lÃª o ficheiro e povoa esse modelo.
#
# Nota: os valores do campo id sÃ£o demasiado complexos para serem usados na aplicaÃ§Ã£o pelo utilizador.
#
# Ideia: Cria ids novos, mais simples, tipo: emd00001, emd00002, ..., emd00100, ...

# %%
# Descreve em texto o teu 
# 
# BdEMD = [EMD]
# EMD = [...]
#
# Leitura/carregamento da informaÃ§Ã£o do ficheiro

def lerDataset(fnome):
    f = open(fnome, encoding="utf-8")
    bd = []
    f.readline()
    for linha in f:
            subbd=[]
            a=linha.replace("\n","")
            b=a.split(",")
            d=str(int(b[1])+1)
            b[0]=str("emd"+(str(d.zfill(5))))
            for i in range (0,13):
                if i !=1:
                    subbd.append(b[i])
            bd.append(subbd)
    return bd

# %%
BD = []
BD = lerDataset("emd4.csv")
print(BD)
# Out:
# [['emd00001', '2020-02-25', 'Delgado', 'Gay', '28', 'F', 'Gloucester', 'BTT', 'ACRroriz', 'delgado.gay@acrroriz.biz', 'true', 'true'], ['emd00002', '2019-07-31', 'Foreman', 'Prince', '34', 'M', 'Forestburg', 'Ciclismo', 'ACDRcrespos', 'foreman.prince@acdrcrespos.org', 'false', 'true'], ['emd00003', '2021-01-06', 'Cheryl', 'Berger', '21', 'M', 'Umapine', 'Basquetebol', 'Vitoria', 'cheryl.berger@vitoria.biz', 'false', 'true'], ['emd00004', '2020-11-19', 'Graves', 'Goff', '29', 'F', 'Babb', 'Andebol', 'AVCfamalicão', 'graves.goff@avcfamalicão.co.uk', 'false', 'false'], ['emd00005', '2019-09-01', 'Mckay', 'Bolton', '29', 'F', 'Chilton', 'Futebol', 'ACDRcrespos', 'mckay.bolton@acdrcrespos.me', 'false', 'false'], ['emd00006', '2019-10-07', 'Marla', 'Kelley', '22', 'M', 'Clarence', 'Atletismo', 'AmigosMontanha', 'marla.kelley@amigosmontanha.tv', 'false', 'false'], ['emd00007', '2020-12-11', 'Merrill', 'Maddox', '34', 'M', 'Roderfield', 'Equitação', 'ACRroriz', 'merrill.maddox@acrroriz.com',
# ...

# %% [markdown]
# ## Listagem (exercÃ­cio 2)
#
# Especifica uma funÃ§Ã£o que faÃ§a a listagem no monitor dos vÃ¡rios registos de informaÃ§Ã£o por ordem cronolÃ³gica decrescente.
#
# Tenta dar a forma duma tabela em que as colunas tÃªm todas a mesma dimensÃ£o.

# %%
# Listagem da informaÃ§Ã£o
import pandas as pd

def listarDataset(bd):
    p=bd.copy()
    p.sort(reverse=True, key=org)
    print("id     |Data               |Nome      | Aptidão")
    print("----------------------------------------------")
    for a in bd:
        print(a[0]+' | '+a[1]+' | '+ a[3]+ a[2]
                +' | '+ a[11] )
    
def org (bd):
    data=bd[1]
    return data
(listarDataset(BD))
# Out:
# id     |Data               |Nome      | Aptidão
# ----------------------------------------------
# emd00001 | 2020-02-25 | GayDelgado | true
# emd00002 | 2019-07-31 | PrinceForeman | true
# emd00003 | 2021-01-06 | BergerCheryl | true
# emd00004 | 2020-11-19 | GoffGraves | false
# emd00005 | 2019-09-01 | BoltonMckay | false
# emd00006 | 2019-10-07 | KelleyMarla | false
# emd00007 | 2020-12-11 | MaddoxMerrill | true
# emd00008 | 2019-03-12 | CalderonNikki | false
# emd00009 | 2020-12-09 | BrightLucia | false
# emd00010 | 2020-01-26 | WellsFaith | true
# emd00011 | 2019-03-29 | OsbornMilagros | false
# emd00012 | 2019-09-08 | SellersValentine | true
# emd00013 | 2019-05-10 | HydeMartha | false
# emd00014 | 2019-04-22 | StevensonBeck | false
# emd00015 | 2019-05-05 | StrongLester | false
# emd00016 | 2020-03-19 | BradleySharon | false
# emd00017 | 2019-07-30 | DaleWaters | false
# emd00018 | 2019-07-27 | MayerRebekah | false
# emd00019 | 2020-04-19 | HowellIsabella | false
# ...

# %% [markdown]
# ## Consulta de um registo (exercÃ­cio 3)
#
# Especifica uma funÃ§Ã£o que, dado o id de um EMD, coloca a sua informaÃ§Ã£o no monitor.

# %%
# Consulta de um registo
def consultarDataset(bd, id):
    a=0
    while bd[a][0]!=id:
        a+=1
    return bd[a][11]

# %%
print(consultarDataset(BD,"emd00027"))
# Out:
# false

# %% [markdown]
# ## Modalidades (exercÃ­cio 4)
#
# Especifica um funÃ§Ã£o que dÃ¡ como resultado uma lista de modalidades ordenada alfabeticamente e sem repetiÃ§Ãµes.

# %%
def modalidades(bd):
    modalidade=[]
    for i in bd:
        if i[7] not in modalidade:
            modalidade.append(i[7])
    modalidade.sort()


    return modalidade
print(modalidades(BD))
# Out:
# ['Andebol', 'Atletismo', 'BTT', 'Badminton', 'Basquetebol', 'Ciclismo', 'Dança', 'Equitação', 'Esgrima', 'Futebol', 'Karaté', 'Orientação', 'Parapente', 'Patinagem', 'Triatlo']

# %% [markdown]
# ## DistribuiÃ§Ã£o por modalidade (exercÃ­cio 5)
#
# Especifica uma funÃ§Ã£o que dÃ¡ como resultado uma lista de pares indicando quantos EMD estÃ£o registados em cada modalidade.

# %%
def distribPorModalidade(bd):
    distribuicao = {}
    for a in bd:
        if a[7] in distribuicao.keys():
            distribuicao[a[7]] = distribuicao[a[7]] +1
        else:
            distribuicao[a[7]] = 1
    return distribuicao
print(distribPorModalidade(BD))
# Out:
# {'BTT': 29, 'Ciclismo': 23, 'Basquetebol': 24, 'Andebol': 21, 'Futebol': 21, 'Atletismo': 16, 'Equitação': 13, 'Patinagem': 14, 'Orientação': 17, 'Triatlo': 23, 'Dança': 22, 'Karaté': 21, 'Badminton': 24, 'Esgrima': 15, 'Parapente': 17}

# %% [markdown]
# ## DistribuiÃ§Ã£o por clubes (exercÃ­cio 6)
#
# Especifica uma funÃ§Ã£o que dÃ¡ como resultado uma lista de pares indicando quantos EMD estÃ£o registados por cada clube.

# %%
def distribPorClube(bd):
    distribuicao = {}
    for a in bd:
        if a[8] in distribuicao.keys():
            distribuicao[a[8]] = distribuicao[a[8]] +1
        else:
            distribuicao[a[8]] = 1
    return distribuicao
print(distribPorClube(BD))
# Out:
# {'ACRroriz': 37, 'ACDRcrespos': 41, 'Vitoria': 32, 'AVCfamalicão': 31, 'AmigosMontanha': 35, 'EDViana': 34, 'GDGoma': 26, 'SCBraga': 34, 'ABCbraga': 30}

# %% [markdown]
# ## DistribuiÃ§Ã£o por ano (exercÃ­cio 7)
#
# Especifica uma funÃ§Ã£o que dÃ¡ como resultado uma lista de pares indicando quantos EMD estÃ£o registados por cada ano.

# %%
def distribPorAno(bd):
    distribuicao = {}
    
    for a in bd:
        a=a[1].split("-")
       
        if a[0] in distribuicao.keys():
            distribuicao[a[0]] = distribuicao[a[0]] +1
        else:
            distribuicao[a[0]] = 1
    return distribuicao
print(distribPorAno(BD))
# Out:
# {'2020': 138, '2019': 145, '2021': 17}

# %% [markdown]
# ## DistribuiÃ§Ã£o parametrizada (exercÃ­cio 8)
#
# Especifica uma funÃ§Ã£o que permita calcular uma distribuiÃ§Ã£o por qualquer um dos campos da BD.

# %%
def distrib(bd, index):

    distrib = {}
    for emd in bd :
        if emd[index] in distrib.keys() :
            distrib[emd[index]] = distrib[emd[index]] + 1
        else :
            distrib[emd[index]] = 1
    return distrib
    
distrib(BD, 10)
# Out:
# {'true': 137, 'false': 163}

# %% [markdown]
# # GrÃ¡ficos
#
# ## GrÃ¡fico da distribuiÃ§Ã£o por curso (exercÃ­cio 8)
#
# Especifica uma funÃ§Ã£o que faz o plot dum grÃ¡fico com a distribuiÃ§Ã£o de alunos por modalidade.

# %%
import matplotlib.pyplot as plt

from textwrap import wrap
def plotDistribPorModalidade(distrib):
    _modalidade, _alunos =plt.subplots(figsize=(16,6))

    _modalidade = distrib.keys()
    _alunos = distrib.values()
   
    plt.xlabel("modalidades")
    plt.ylabel("Nº de alunos")
    plt.title("Distribuição por modalidade:")
    plt.bar(_modalidade,_alunos, linewidth=2
    , color=["pink", "red"])
plotDistribPorModalidade(distribPorModalidade(lerDataset("emd4.csv")))

# %% [markdown]
# ## GrÃ¡fico duma distribuiÃ§Ã£o qualquer (exercÃ­cio 9)
#
# Especifica uma funÃ§Ã£o que faz o plot dum grÃ¡fico com a distribuiÃ§Ã£o passada como argumento.
#
# Nota: Que parÃ¢metros sÃ£o necessÃ¡rios para ter uma funÃ§Ã£o genÃ©rica que trace o grÃ¡fico para qualquer distribuiÃ§Ã£o?

# %%
import matplotlib.pyplot as plt

from textwrap import wrap
def plotDistrib(distrib):
    index, _alunos =plt.subplots(figsize=(18,6))

    index = distrib.keys()
    _alunos = distrib.values()
   
    plt.xlabel("modalidades")
    plt.ylabel("Nº de alunos")
    plt.title("Distribuição por modalidade:")
    plt.bar(index,_alunos, linewidth=2
    , color=["pink", "red"])
plotDistrib(distrib(BD,10))

# %%
###!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!PARTE DA APLICAÇAO !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
import PySimpleGUI as sg
sg.theme('DarkTeal11')
BD=lerDataset("emd4.csv")
res=[]
interface=[[sg.Text("Parâmetros do exame: id, data, nome, idade, género, morada, modalidade, clube, email, federado, resultado")], 
           [sg.Button("Listar Exames")],
           [sg.Button("Consultar Exame")],
           [sg.Button("Lista de Modalidades")],
           [sg.Button("Distribuições")],
           [sg.Button("Gráficos")],
           
           [sg.Listbox(values=res,size=(100,20), key="_Resultado")],
           [sg.Button("Sair")]
          ]

window = sg.Window("Exames Médicos", interface)

stop = False
while not stop:
    event, values = window.read()
    if event == "Sair" or event == sg.WIN_CLOSED:
        stop = True
        
    elif event=="Listar Exames":   
        res=[]
        window["_Resultado"].update(values=res)
        res=listarDataset(BD)
        window["_Resultado"].update(values=res)
        
    elif event=="Consultar Exame":
        res=[]
        window["_Resultado"].update(values=res)
        interid = [[sg.Text('Id do paciente: ', size=(10, 1)), sg.InputText(key='_Id')],[sg.Button('Inserir')]]

        wid = sg.Window('Inserir id', interid)
        inputEventid, inputValuesid = wid.read(close=True)
        wid.close()
        if inputEventid == 'Inserir':
            res=[]
            res.append(consultarDataset(BD,str(inputValuesid['_Id'])))
            res.append(" ")
        window["_Resultado"].update(values=res)
        
    elif event=="Lista de Modalidades":
        res=[]
        window["_Resultado"].update(values=res)
        res=modalidades(BD)
        window["_Resultado"].update(values=res)
    
    elif event=="Distribuições":
        res=[]
        window["_Resultado"].update(values=res)
        formLayout = [[sg.Button("Distribuição por modalidade")],
                 [sg.Button("Distribuição por clube")],
                 [sg.Button("Distribuição por ano")],
                 [sg.Button("Distribuição por estado de federado")],
                 [sg.Button("Distribuição por resultado do teste")],
                 [sg.Button("Distribuição por idade")],
                 [sg.Button("Distribuição por género")]]

        wform = sg.Window('Distribuições', formLayout)
        inputEvent, inputValues = wform.read(close=True)
     
        if inputEvent == "Inserir" or event == sg.WIN_CLOSED:
            stop = True 
            
        elif inputEvent=="Distribuição por ano":
            ano=distribPorAno(BD)
            res.append("Ano: Nº de exames realizados")
            for a in ano:
                res.append(str(a)+": "+str(ano[a]))
            window["_Resultado"].update(values=res)   
        elif inputEvent=="Distribuição por modalidade":
            mod=distribPorModalidade(BD)
            res.append("modalidade: Nº de exames realizados")
            for a in mod:
                res.append(str(a)+": "+str(mod[a]))
            window["_Resultado"].update(values=res) 
        elif inputEvent=="Distribuição por clube":
        
            clube=distribPorModalidade(BD)
            res.append("clube: Nº de exames realizados")
            for a in clube:
                res.append(str(a)+": "+str(clube[a]))
            window["_Resultado"].update(values=res) 
             

        elif inputEvent=="Distribuição por estado de federado":
            federado=distrib(BD,9)
            res.append("federado: Nº de exames realizados")
            for a in federado:
                res.append(str(a)+": "+str(federado[a]))
            window["_Resultado"].update(values=res) 
            
                    
        elif inputEvent=="Distribuição por resultado do teste":
            
            resu=distrib(BD,10)
            res.append("federado: Nº de exames realizados")
            for a in resu:
                res.append(str(a)+": "+str(resu[a]))
            window["_Resultado"].update(values=res) 
  
        elif inputEvent=="Distribuição por idade":
            resua=distrib(BD,4)
            res.append("federado: Nº de exames realizados")
            for a in resua:
                res.append(str(a)+": "+str(resua[a]))
            window["_Resultado"].update(values=res) 
            
        elif inputEvent=="Distribuição por género":  
            gen=distrib(BD,3)
            res.append("federado: Nº de exames realizados")
            for a in gen:
                res.append(str(a)+": "+str(gen[a]))
            window["_Resultado"].update(values=res) 
        
    elif event=="Gráficos":
        res=[]
        window["_Resultado"].update(values=res)
        grafLayout = [[sg.Button("Gráfico da distribuição por modalidade")],
                 [sg.Button("Gráfico da distribuição por clube")],
                 [sg.Button("Gráfico da distribuição por ano")],
            ]
                 

        wgraf=sg.Window('Distribuições', grafLayout)
        Eventgraf, Valuesgraf = wgraf.read(close=True)
 
        if Eventgraf=="Gráfico da distribuição por modalidade":
             res=[]
             window["_Resultado"].update(values=res)
             res=plotDistribPorModalidade(distribPorModalidade(lerDataset("emd4.csv")))
             window["_Resultado"].update(values=res) 
        
        elif  Eventgraf=="Gráfico da distribuição por clube":
             res=[]
             window["_Resultado"].update(values=res)
             res=plotDistrib(distrib(BD,8))
             window["_Resultado"].update(values=res) 
            
            
        elif Eventgraf=="Gráfico da distribuição por ano":
             res=[]
             window["_Resultado"].update(values=res)
             res=plotDistrib(distribPorAno(BD))
             
             window["_Resultado"].update(values=res)  
        
window.close()
# Out:
# id     |Data               |Nome      | Aptidão
# ----------------------------------------------
# emd00001 | 2020-02-25 | GayDelgado | true
# emd00002 | 2019-07-31 | PrinceForeman | true
# emd00003 | 2021-01-06 | BergerCheryl | true
# emd00004 | 2020-11-19 | GoffGraves | false
# emd00005 | 2019-09-01 | BoltonMckay | false
# emd00006 | 2019-10-07 | KelleyMarla | false
# emd00007 | 2020-12-11 | MaddoxMerrill | true
# emd00008 | 2019-03-12 | CalderonNikki | false
# emd00009 | 2020-12-09 | BrightLucia | false
# emd00010 | 2020-01-26 | WellsFaith | true
# emd00011 | 2019-03-29 | OsbornMilagros | false
# emd00012 | 2019-09-08 | SellersValentine | true
# emd00013 | 2019-05-10 | HydeMartha | false
# emd00014 | 2019-04-22 | StevensonBeck | false
# emd00015 | 2019-05-05 | StrongLester | false
# emd00016 | 2020-03-19 | BradleySharon | false
# emd00017 | 2019-07-30 | DaleWaters | false
# emd00018 | 2019-07-27 | MayerRebekah | false
# emd00019 | 2020-04-19 | HowellIsabella | false
# ...
